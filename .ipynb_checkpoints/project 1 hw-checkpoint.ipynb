# %%
dct = {}
dct = {"name": "logan schumacher", 
       "major/minor":"finance/econ.", 
       "reason for taking this class": "you told me this could be a good class to develop some useful skills for the future",
       " my plans for after ndsu" : "are to get a job in a bank to start building experience"}
dct
# Out:
# {'name': 'logan schumacher',
#  'major/minor': 'finance/econ.',
#  'reason for taking this class': 'you told me this could be a good class to develop some useful skills for the future',
#  ' my plans for after ndsu': 'are to get a job in a bank to start building experience'}

# %%
import pandas as pd
df = pd.DataFrame(dct, index = ["name"])
df
# Out:
#                   name    major/minor  \
# name  logan schumacher  finance/econ.
#
#                            reason for taking this class  \
# name  you told me this could be a good class to deve...
#
#                                 my plans for after ndsu
# name  are to get a job in a bank to start building e...

# %%
dct = {"Raymond March": {},
       "Tim Petry": {},
       "Xudong Rao":{}, 
       "David Ripplinger":{},
       "Andrew Swenson":{}, 
       "Zachary Machunda":{},
       "Dragan Miljkovic":{}, 
       "Frayne Olson":{}, 
       "Robert Hearne":{}}

dct
# Out:
# {'Raymond March': {},
#  'Tim Petry': {},
#  'Xudong Rao': {},
#  'David Ripplinger': {},
#  'Andrew Swenson': {},
#  'Zachary Machunda': {},
#  'Dragan Miljkovic': {},
#  'Frayne Olson': {},
#  'Robert Hearne': {}}

# %%
dct["Raymond March"]["website"] = "https://www.ndsu.edu/centers/pcpe/about/directory/raymond_march/"
dct["Raymond March"]["Areas of Specialization"] = "public and private provision and governance of health care in the United States, particularly in pharmaceutical markets."
dct["Raymond March"]["bio"] = "Raymond is also a research fellow at the Independent Institute and the director of FDAReview.org, an educational research and communications project on the U.S. Food and Drug Administration (FDA). He regularly blogs on health policy at The Beacon. Raymond resides in Fargo with his wife, Amy, daughter Tinsley, son Grant, and two ill-behaved cats"
dct["Tim Petry"]["Website"] = "https://www.ndsu.edu/agecon/faculty/petry/"
dct["Tim Petry"]["Areas of Specialization"] = "Agricultural Economics"
dct["Tim Petry"]["Bio"] = "Tim Petry was raised on a livestock ranch in Northwestern North Dakota. He graduated from North Dakota State University with a major in Agricultural Economics in 1969 and served two years in the US Army. Petry returned to NDSU and completed a Master’s Degree in Agricultural Economics with an agricultural marketing emphasis in1973."
dct["Xudong Rao"]["Website"] = "https://www.ndsu.edu/agecon/faculty/rao/"
dct["Xudong Rao"]["Areas of Specialization"] = "Farm and Agribusiness Management, Risk Analysis, Efficiency and Productivity, Technology Adoption, Food and Agricultural Policy, International Agricultural Development"
dct["Xudong Rao"]["Bio"] = "unknown"
dct["David Ripplinger"]["Website"] = "https://www.ndsu.edu/agecon/faculty/ripplinger/"
dct["David Ripplinger"]["Areas of Specialization"] = "Transportation and Logistics, Agricultural Economics"
dct["David Ripplinger"]["Bio"] = "unknown"
dct["Andrew Swenson"]["Website"] = "https://www.ndsu.edu/agecon/faculty/swenson/"
dct["Andrew Swenson"]["Areas of Specialization"] = "Economics,Geography,Agriculture Economics"
dct["Andrew Swenson"]["Bio"] = "unknown"
dct["Zachary Machunda"]["Website"] = "https://www.ndsu.edu/agecon/faculty/machunda/"
dct["Zachary Machunda"]["Areas of Specialization"] = "Economic Geography, Policy Analysis, Labor Economics, Monetary Economics and Development Economics, Economics and Education"
dct["Zachary Machunda"]["Bio"] = "Unknown"
dct["Dragan Miljkovic"]["Website"] = "https://www.ndsu.edu/agecon/faculty/miljkovic/"
dct["Dragan Miljkovic"]["Areas of Specialization"] = "Economics, Agricultural Economics"
dct["Dragan Miljkovic"]["Bio"] = "unknown"
dct["Frayne Olson"]["Website"] = "https://www.ndsu.edu/agecon/faculty/olson/"
dct["Frayne Olson"]["Areas of Specialization"] = "Crop Economist/Marketing"
dct["Frayne Olson"]["Bio"] = "Unknown"
dct["Robert Hearne"]["Website"] = "https://www.ndsu.edu/agecon/faculty/hearne/"
dct["Robert Hearne"]["Areas of Specialization"] = "Agricultural and Applied Economics"
dct["Robert Hearne"]["Bio"] = "Dr. Bob Hearne has been in the Department of Agribusiness and Applied Economics since 2002.   His research focuses on water resources management institutions, water markets, protected area management, and the economic valuation of environmental goods and services.  He has professional experience in Europe, Asia, Latin America, and Asia. "


dct
# Out:
# {'Raymond March': {'website': 'https://www.ndsu.edu/centers/pcpe/about/directory/raymond_march/',
#   'Areas of Specialization': 'public and private provision and governance of health care in the United States, particularly in pharmaceutical markets.',
#   'bio': 'Raymond is also a research fellow at the Independent Institute and the director of FDAReview.org, an educational research and communications project on the U.S. Food and Drug Administration (FDA). He regularly blogs on health policy at The Beacon. Raymond resides in Fargo with his wife, Amy, daughter Tinsley, son Grant, and two ill-behaved cats'},
#  'Tim Petry': {'Website': 'https://www.ndsu.edu/agecon/faculty/petry/',
#   'Areas of Specialization': 'Agricultural Economics',
# ...

# %%
import pandas as pd
df = pd.DataFrame(dct)
df
# Out:
#                                                              Raymond March  \
# website                  https://www.ndsu.edu/centers/pcpe/about/direct...
# Areas of Specialization  public and private provision and governance of...
# bio                      Raymond is also a research fellow at the Indep...
# Website                                                                NaN
# Bio                                                                    NaN
#
#                                                                  Tim Petry  \
# website                                                                NaN
# Areas of Specialization                             Agricultural Economics
# bio                                                                    NaN
# Website                         https://www.ndsu.edu/agecon/faculty/petry/
# Bio                      Tim Petry was raised on a livestock ranch in N...
#
# ...
